# %%
import pandas as pd
population = pd.read_json("./abs_regional_population_sa2_2001_2020-4826266136351011880.json")

# %%
population.to_json('./abs_regional_population_sa2_2001_2020-4826266136351011880.json')

# %%
population.head()
# Out:
#        sa2_name_2016     area_km2  gccsa_name_2016   state_code_2016  \
# 0          Braidwood  3418.352539      Rest of NSW                 1
# 1            Karabar     6.982500      Rest of NSW                 1
# 2         Queanbeyan     4.763400      Rest of NSW                 1
# 3  Deua - Wadbilliga  2781.998779      Rest of NSW                 1
# 4               Eden    94.813797      Rest of NSW                 1
#
#    state_name_2016   sa2_maincode_2016   sa4_code_2016  \
# 0  New South Wales           101021007             101
# 1  New South Wales           101021008             101
# 2  New South Wales           101021009             101
# 3  New South Wales           101041022             101
# 4  New South Wales           101041023             101
#
#     pop_density_2020_people_per_km2   sa4_name_2016  gccsa_code_2016  \
# 0                          1.255300  Capital Region            1RNSW
# 1                       1198.854248  Capital Region            1RNSW
# ...
